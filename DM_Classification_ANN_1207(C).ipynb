# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime as dt
from pandas import read_excel
from pandas import read_csv
from pandas import concat
from pandas import merge
import pandas as pd
import numpy as np
from pandas import Series
from pandas import DataFrame
import re


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler

from statsmodels.formula.api import ols

from matplotlib import pyplot as plt
import seaborn as sns

# %%
import os
os.chdir(r'C:\Users\82102\OneDrive\바탕 화면\dataset\MFC')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_for_classification.csv', encoding='UTF8', index_col = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 468
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GAS_STATION   469 non-null    object
#  1   DISTRICT      469 non-null    object
#  2   DONG          469 non-null    object
#  3   LATITUDE      469 non-null    float64
#  4   LONGITUDE     469 non-null    float64
#  5   AREA          469 non-null    float64
#  6   ESTATE        469 non-null    float64
#  7   DIST_EASTDC   469 non-null    float64
#  8   DIST_WESTDC   469 non-null    float64
#  9   DIST_KOREADC  469 non-null    float64
#  10  POP100        469 non-null    int64
#  11  POP500        469 non-null    int64
#  12  POP1000       469 non-null    int64
#  13  SCHOOL        469 non-null    int64
#  14  APART         469 non-null    int64
#  15  MARKET        469 non-null    int64
# dtypes: float64(7), int64(6), object(3)
# memory usage: 62.3+ KB

# %%
df.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET
# 0    15660       5      1      58
# 1    25467       9      2       6
# 2    26924       9      1      22
# 3    30288       5      2       4
# 4    27394       9      6      20

# %%
## correlation
colormap = plt.cm.viridis
plt.figure(figsize=(15,15))
plt.title('Pearson Correlation of Features', size=15)

sns.heatmap(df.iloc[:,5:].astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
values = df.iloc[:,[5,6,7,8,9,12,13,14,15]]
values = values.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_ = MinMaxScaler()
scaler_.fit(values)
scaled_ = scaler_.transform(values)

scaled__df = pd.DataFrame(scaled_, columns=df.columns[[5,6,7,8,9,12,13,14,15]])
scaled__df
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET
# 0    0.357143  0.018519  0.983051
# 1    0.642857  0.037037  0.101695
# 2    0.642857  0.018519  0.372881
# 3    0.357143  0.037037  0.067797
# 4    0.642857  0.111111  0.338983
# ..        ...       ...       ...
# 464  0.285714  0.018519  0.000000
# 465  0.285714  0.018519  0.000000
# 466  0.000000  0.000000  0.067797
# 467  0.214286  0.018519  0.033898
# 468  0.285714  0.055556  0.067797
#
# [469 rows x 9 columns]

# %% [markdown]
# According to AHP analysis, we set weight of features.
# * Weight
#     - AREA = 0.198
#     - ESTATE = 0.327
#     - DISTANCE = 0.124
#     - POPULATION = 0.244
#     - SCHOOL = 0.02
#     - APARTMENT = 0.04
#     - MARKET = 0.048

# %%
# AHP
dfdf = scaled__df.copy()
dfdf['SCORE'] = dfdf['AREA']*0.198 - dfdf['ESTATE']*0.327 - dfdf['DIST_EASTDC']*0.0413 - dfdf['DIST_WESTDC']*0.0413 - dfdf['DIST_KOREADC']*0.0413 + dfdf['POP1000']*0.244 + dfdf['SCHOOL']*0.02 + dfdf['APART']*0.04 + dfdf['MARKET']*0.048

# %%
dfdf
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET     SCORE
# 0    0.357143  0.018519  0.983051  0.013764
# 1    0.642857  0.037037  0.101695 -0.037691
# 2    0.642857  0.018519  0.372881  0.008770
# 3    0.357143  0.037037  0.067797  0.053482
# 4    0.642857  0.111111  0.338983  0.016702
# ..        ...       ...       ...       ...
# 464  0.285714  0.018519  0.000000 -0.003007
# 465  0.285714  0.018519  0.000000  0.036476
# 466  0.000000  0.000000  0.067797 -0.007620
# 467  0.214286  0.018519  0.033898  0.032797
# 468  0.285714  0.055556  0.067797  0.053926
#
# [469 rows x 10 columns]

# %%
df['SCORE_CAT'] = pd.qcut(dfdf.SCORE ,4, labels=['매우부적합', '부적합', '적합', '매우적합'])
df
# Out:
#              GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0     현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1         선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2       현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3                  서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4           ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
# ..                   ...      ...    ...        ...         ...     ...
# 464  현대오일뱅크㈜직영 도봉현대셀프주유소      도봉구    도봉동  37.688374  127.045327  1366.0
# 465         GS칼텍스㈜ 도봉주유소      도봉구    도봉동  37.684369  127.045522  1640.7
# 466     (주)송만에너지 도봉제일주유소      도봉구    도봉동  37.674474  127.044067   271.0
# 467               노원교주유소      도봉구    도봉동  37.679015  127.049751   815.0
# 468                오복주유소      도봉구    방학동  37.662280  127.047441   591.0
#
#          ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0     8280000.0     8.970251    13.202286     11.678968     166    4465
# 1    18850000.0     9.568763    12.593357     11.494239     349    7404
# 2    15050000.0     9.713120    12.454393     11.199948     251    7069
# 3    10330000.0     9.772973    12.403577     11.855362     102    8374
# 4    13300000.0    11.006969    11.272070     10.639303     186    5401
# ..          ...          ...          ...           ...     ...     ...
# 464   4205000.0    12.288585    26.954691     25.294460      16    4651
# 465   4395000.0    11.849594    26.639204     24.849744     180    9341
# 466   5671000.0    10.807711    25.756175     23.746627     465    7251
# 467   5380000.0    11.191130    26.466958     24.267332      55    9057
# 468   4816000.0     9.420522    25.024822     22.399970     247    6762
#
#      POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 0      15660       5      1      58       부적합
# 1      25467       9      2       6     매우부적합
# 2      26924       9      1      22       부적합
# 3      30288       5      2       4        적합
# 4      27394       9      6      20       부적합
# ..       ...     ...    ...     ...       ...
# 464    12421       4      1       0     매우부적합
# 465    18592       4      1       0       부적합
# 466    28101       0      0       4     매우부적합
# 467    30149       3      1       2       부적합
# 468    34359       4      3       4        적합
#
# [469 rows x 17 columns]

# %%
feature_cols = df.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df[feature_cols]
y = df.SCORE_CAT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (328, 9) (328,)
# (141, 9) (141,)

# %%
y_train.value_counts()
# Out:
# 부적합      87
# 적합       86
# 매우적합     82
# 매우부적합    73
# Name: SCORE_CAT, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier , AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
clf = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
predicted=clf.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_clf = 'Accuracy Score :', accuracy_score(y_test, predicted)
print(accuracy_score_clf)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[35  0  9  1]
#  [ 0 33  0  2]
#  [10  0 16  4]
#  [ 0  5  4 22]]
# ('Accuracy Score :', 0.75177304964539)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.78      0.78      0.78        45
#         매우적합       0.87      0.94      0.90        35
#          부적합       0.55      0.53      0.54        30
#           적합       0.76      0.71      0.73        31
#
#     accuracy                           0.75       141
#    macro avg       0.74      0.74      0.74       141
# weighted avg       0.75      0.75      0.75       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , clf.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.210732
# ESTATE                  0.191658
# DIST_EASTDC             0.025755
# DIST_WESTDC             0.047889
# DIST_KOREADC            0.051467
# POP1000                 0.356623
# SCHOOL                  0.041029
# APART                   0.025217
# MARKET                  0.049629

# %%
lr = LogisticRegression(C=20, max_iter=1000, random_state=0).fit(X_train, y_train)
predicted=lr.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_lr = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_lr)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[31  1 12  1]
#  [ 0 29  3  3]
#  [ 0  3 21  6]
#  [ 1 12  5 13]]
# ('Accuracy Score :', 0.6666666666666666)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.97      0.69      0.81        45
#         매우적합       0.64      0.83      0.73        35
#          부적합       0.51      0.70      0.59        30
#           적합       0.57      0.42      0.48        31
#
#     accuracy                           0.67       141
#    macro avg       0.67      0.66      0.65       141
# weighted avg       0.70      0.67      0.67       141

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=11).fit(X_train_scaled, y_train)
predicted=knn.predict(X_test_scaled)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_knn = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_knn)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[34  1  9  1]
#  [ 0 26  1  8]
#  [ 3  1 15 11]
#  [ 0  5  7 19]]
# ('Accuracy Score :', 0.6666666666666666)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.92      0.76      0.83        45
#         매우적합       0.79      0.74      0.76        35
#          부적합       0.47      0.50      0.48        30
#           적합       0.49      0.61      0.54        31
#
#     accuracy                           0.67       141
#    macro avg       0.67      0.65      0.66       141
# weighted avg       0.70      0.67      0.68       141

# %%
forest = RandomForestClassifier(max_depth = 12, random_state=0).fit(X_train, y_train)
predicted=forest.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_forest = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_forest)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[37  0  8  0]
#  [ 0 31  2  2]
#  [ 4  0 19  7]
#  [ 2  7  2 20]]
# ('Accuracy Score :', 0.7588652482269503)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.86      0.82      0.84        45
#         매우적합       0.82      0.89      0.85        35
#          부적합       0.61      0.63      0.62        30
#           적합       0.69      0.65      0.67        31
#
#     accuracy                           0.76       141
#    macro avg       0.74      0.75      0.74       141
# weighted avg       0.76      0.76      0.76       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , forest.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.136232
# ESTATE                  0.159847
# DIST_EASTDC             0.083291
# DIST_WESTDC             0.072984
# DIST_KOREADC            0.091123
# POP1000                 0.301456
# SCHOOL                  0.041859
# APART                   0.069904
# MARKET                  0.043305

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Feature Importance', y='Feature Name', data=pd.DataFrame([(i, j) for i, j in zip(feature_cols , forest.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name').reset_index())
plt.title('Random Forest Feature Importances', fontsize=18)
plt.show()

# %%
gb = GradientBoostingClassifier(max_depth=7, random_state=0).fit(X_train, y_train)
predicted=gb.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_gb = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_gb)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[38  0  7  0]
#  [ 0 29  1  5]
#  [ 5  0 19  6]
#  [ 0  4  5 22]]
# ('Accuracy Score :', 0.7659574468085106)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.88      0.84      0.86        45
#         매우적합       0.88      0.83      0.85        35
#          부적합       0.59      0.63      0.61        30
#           적합       0.67      0.71      0.69        31
#
#     accuracy                           0.77       141
#    macro avg       0.76      0.75      0.75       141
# weighted avg       0.77      0.77      0.77       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , gb.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.159759
# ESTATE                  0.211988
# DIST_EASTDC             0.051810
# DIST_WESTDC             0.029212
# DIST_KOREADC            0.071025
# POP1000                 0.399160
# SCHOOL                  0.037593
# APART                   0.026438
# MARKET                  0.013017

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Feature Importance', y='Feature Name', data=pd.DataFrame([(i, j) for i, j in zip(feature_cols , gb.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name').reset_index())
plt.title('Gradient Boosting Classifier Feature Importances', fontsize=18)
plt.show()

# %% [markdown]
# If we have a more time, we are going to adopt adaboost or xgboost, LGBM etc..

# %% [markdown]
# ## ANN

# %%
df['SCORE_CAT']
# Out:
# 0        부적합
# 1      매우부적합
# 2        부적합
# 3         적합
# 4        부적합
#        ...
# 464    매우부적합
# 465      부적합
# 466    매우부적합
# 467      부적합
# 468       적합
# Name: SCORE_CAT, Length: 469, dtype: category
# Categories (4, object): ['매우부적합' < '부적합' < '적합' < '매우적합']

# %%
# 라벨 인코딩
# 1대1 매칭시켜도 되는데
# 수업 컨텐츠 사용할려고
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['SCORE_CAT'])
label_encoded = le.transform(df['SCORE_CAT'])


label_df = pd.DataFrame(label_encoded, 
                       columns = ['Score_label'])

label_df.head()
# Out:
#    Score_label
# 0            2
# 1            0
# 2            2
# 3            3
# 4            2

# %%
# 매우부적합 : 0
# 부적합 : 2
# 적합 : 3
# 매우적합 : 1
df_ann = pd.concat([df, label_df], axis =  1)
df_ann.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET SCORE_CAT  Score_label
# 0    15660       5      1      58       부적합            2
# 1    25467       9      2       6     매우부적합            0
# 2    26924       9      1      22       부적합            2
# 3    30288       5      2       4        적합            3
# 4    27394       9      6      20       부적합            2

# %%
feature_cols = df_ann.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df_ann[feature_cols]
y = df_ann['Score_label']

# %%
# (x_train, y_train), (x_test, y_test) 데이터 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)

# %%
# 데이터 정규화해서 스케일 낮추기
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# train 데이터 분리 (train/valid)
train_scaled, val_scaled, train_target, val_target = train_test_split(X_train_scaled, y_train, test_size=0.3, random_state=1113)

# %%
# dense 조합 바꿔가면서 보기
neural_model = Sequential()

neural_model.add(Dense(64, activation = 'relu', input_shape = (9, )))
neural_model.add(Dense(32, activation = 'relu'))
neural_model.add(Dense(8, activation = 'relu'))
neural_model.add(Dense(4, activation = 'softmax'))


neural_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_accuracy']) 
neural_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 8)                 264
#
#  dense_3 (Dense)             (None, 4)                 36
#
# =================================================================
# Total params: 3,020
# Trainable params: 3,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = neural_model.fit(train_scaled, train_target, epochs = 1000, validation_data = (val_scaled, val_target),
                         callbacks = [EarlyStopping(monitor = 'val_loss', patience=10, verbose = 1),
                                     ReduceLROnPlateau(monitor = 'val_loss', patience = 10, factor = 0.1, min_lr=0.0001, verbose = 1)])


result_df = pd.DataFrame(result.history)
result_df['score'] = result_df.index+1
result_df.set_index('score', inplace = True)
result_df
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 5s 134ms/step - loss: 1.3937 - sparse_categorical_accuracy: 0.2620 - val_loss: 1.3828 - val_sparse_categorical_accuracy: 0.3232 - lr: 0.0010
# Epoch 2/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3824 - sparse_categorical_accuracy: 0.2969 - val_loss: 1.3725 - val_sparse_categorical_accuracy: 0.3636 - lr: 0.0010
# Epoch 3/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3737 - sparse_categorical_accuracy: 0.3013 - val_loss: 1.3641 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 4/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 1.3642 - sparse_categorical_accuracy: 0.2576 - val_loss: 1.3561 - val_sparse_categorical_accuracy: 0.3030 - lr: 0.0010
# Epoch 5/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.3560 - sparse_categorical_accuracy: 0.3057 - val_loss: 1.3495 - val_sparse_categorical_accuracy: 0.3434 - lr: 0.0010
# Epoch 6/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 1.3479 - sparse_categorical_accuracy: 0.2795 - val_loss: 1.3383 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 7/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 1.3373 - sparse_categorical_accuracy: 0.2533 - val_loss: 1.3296 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 8/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 1.3261 - sparse_categorical_accuracy: 0.2533 - val_loss: 1.3179 - val_sparse_categorical_accuracy: 0.2727 - lr: 0.0010
# Epoch 9/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3134 - sparse_categorical_accuracy: 0.2620 - val_loss: 1.3110 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 10/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 1.3004 - sparse_categorical_accuracy: 0.2620 - val_loss: 1.2951 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 11/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 1.2874 - sparse_categorical_accuracy: 0.2489 - val_loss: 1.2798 - val_sparse_categorical_accuracy: 0.2727 - lr: 0.0010
# Epoch 12/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2721 - sparse_categorical_accuracy: 0.2489 - val_loss: 1.2680 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 13/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2539 - sparse_categorical_accuracy: 0.2795 - val_loss: 1.2518 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 14/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2379 - sparse_categorical_accuracy: 0.2620 - val_loss: 1.2337 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 15/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2198 - sparse_categorical_accuracy: 0.2707 - val_loss: 1.2163 - val_sparse_categorical_accuracy: 0.3232 - lr: 0.0010
# Epoch 16/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 1.2034 - sparse_categorical_accuracy: 0.3930 - val_loss: 1.1974 - val_sparse_categorical_accuracy: 0.4040 - lr: 0.0010
# Epoch 17/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 1.1784 - sparse_categorical_accuracy: 0.4192 - val_loss: 1.1738 - val_sparse_categorical_accuracy: 0.4040 - lr: 0.0010
# Epoch 18/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1541 - sparse_categorical_accuracy: 0.4323 - val_loss: 1.1489 - val_sparse_categorical_accuracy: 0.4747 - lr: 0.0010
# Epoch 19/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 1.1279 - sparse_categorical_accuracy: 0.5284 - val_loss: 1.1252 - val_sparse_categorical_accuracy: 0.5253 - lr: 0.0010
# Epoch 20/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0944 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.0936 - val_sparse_categorical_accuracy: 0.5253 - lr: 0.0010
# Epoch 21/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0628 - sparse_categorical_accuracy: 0.5546 - val_loss: 1.0603 - val_sparse_categorical_accuracy: 0.5455 - lr: 0.0010
# Epoch 22/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0280 - sparse_categorical_accuracy: 0.6157 - val_loss: 1.0164 - val_sparse_categorical_accuracy: 0.6061 - lr: 0.0010
# Epoch 23/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9926 - sparse_categorical_accuracy: 0.6725 - val_loss: 0.9846 - val_sparse_categorical_accuracy: 0.6263 - lr: 0.0010
# Epoch 24/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9548 - sparse_categorical_accuracy: 0.6725 - val_loss: 0.9613 - val_sparse_categorical_accuracy: 0.6566 - lr: 0.0010
# Epoch 25/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.9173 - sparse_categorical_accuracy: 0.6943 - val_loss: 0.9166 - val_sparse_categorical_accuracy: 0.7071 - lr: 0.0010
# Epoch 26/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8724 - sparse_categorical_accuracy: 0.7249 - val_loss: 0.8619 - val_sparse_categorical_accuracy: 0.7374 - lr: 0.0010
# Epoch 27/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8327 - sparse_categorical_accuracy: 0.7598 - val_loss: 0.8145 - val_sparse_categorical_accuracy: 0.7475 - lr: 0.0010
# Epoch 28/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7984 - sparse_categorical_accuracy: 0.7380 - val_loss: 0.7890 - val_sparse_categorical_accuracy: 0.7778 - lr: 0.0010
# Epoch 29/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.7608 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.7579 - val_sparse_categorical_accuracy: 0.7778 - lr: 0.0010
# Epoch 30/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7283 - sparse_categorical_accuracy: 0.7948 - val_loss: 0.7291 - val_sparse_categorical_accuracy: 0.7677 - lr: 0.0010
# Epoch 31/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.7069 - sparse_categorical_accuracy: 0.7904 - val_loss: 0.7251 - val_sparse_categorical_accuracy: 0.7576 - lr: 0.0010
# Epoch 32/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6776 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.6731 - val_sparse_categorical_accuracy: 0.8384 - lr: 0.0010
# Epoch 33/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.
ig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 5), dpi = 150)

# 1) 훈련 및 검증 손실 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'loss', color = 'darkblue', label = 'train 손실률', ax = ax1)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_loss', color = 'orange', label = 'valid 손실률', ax = ax1)
ax1.set_title('훈련 및 검증 손실률')
ax1.set_xlabel('반복회차(Epoch)')
ax1.set_ylabel('손실률(Loss)')
ax1.grid()
ax1.legend()

# 2) 훈련 및 검증 절대오차 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'sparse_categorical_accuracy', color = 'darkblue', label = 'train accuracy', ax = ax2)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_sparse_categorical_accuracy', color = 'orange', label = 'test val_accuracy', ax = ax2)
ax2.set_title('훈련 및 검증 accuracy')
ax2.set_xlabel('반복회차(Epoch)')
ax2.set_ylabel('accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
df_final_test_for_map = df[df.index.isin(X_test.index) == True]

# %%
df_final_test_for_map
# Out:
#              GAS_STATION DISTRICT DONG   LATITUDE   LONGITUDE    AREA  \
# 1         선익상사(주) 동자동주유소      용산구  동자동  37.550201  126.972418   711.0
# 6        현대오일뱅크㈜ 직영강변주유소      용산구  청암동  37.534714  126.945724  1090.0
# 8         (주)중앙에너비스 한남지점      용산구  한남동  37.534723  127.006108   365.0
# 9         한남제3한강주유소 주식회사      용산구  한남동  37.532879  127.007511   764.0
# 11      현대오일뱅크㈜ 직영한남동주유소      용산구  한남동  37.546073  127.002896   851.0
# ..                   ...      ...  ...        ...         ...     ...
# 456         ㈜자연에너지 햇살주유소      도봉구  방학동  37.663105  127.036402  1114.0
# 461          동일석유㈜ 창동주유소      도봉구   창동  37.644631  127.032708   895.0
# 462          극동유화㈜ 대안주유소      도봉구   창동  37.661514  127.047500  1050.0
# 463      한이에너지㈜ KLP제1주유소      도봉구   창동  37.657768  127.040593   610.0
# 464  현대오일뱅크㈜직영 도봉현대셀프주유소      도봉구  도봉동  37.688374  127.045327  1366.0
#
#          ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 1    18850000.0     9.568763    12.593357     11.494239     349    7404
# 6     5880000.0    12.401077     9.805181     11.566847      85    4803
# 8    19850000.0     7.848220    14.981754      8.676071      80    4913
# 9    24360000.0     7.889487    15.066218      8.442066     395    5125
# 11   10510000.0     7.340386    14.997967      9.962473       5    2275
# ..          ...          ...          ...           ...     ...     ...
# 456   5397000.0     9.795325    24.385253     22.477457     402   11785
# 461   6121000.0     8.036470    22.746379     20.428315     451   12856
# 462   4215000.0     9.336797    24.970794     22.315055     415    7272
# 463   6197000.0     9.113027    24.241694     21.884481     334   10668
# 464   4205000.0    12.288585    26.954691     25.294460      16    4651
#
#      POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 1      25467       9      2       6     매우부적합
# 6      19479       1      2       1       부적합
# 8      16531       0      0       2     매우부적합
# 9      15595       0      0       1     매우부적합
# 11     14443       2      0       0     매우부적합
# ..       ...     ...    ...     ...       ...
# 456    40943       1      5       5      매우적합
# 461    42972       1      7       3      매우적합
# 462    33088       5      3       4        적합
# 463    39755       4      4       4        적합
# 464    12421       4      1       0     매우부적합
#
# [141 rows x 17 columns]

# %%
# 용이가 한 코드로 지도시각화
import folium as g

df_final_test_for_map = df[df.index.isin(X_test.index) == True]

seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df_final_test_for_map)):
    name = df_final_test_for_map.iloc[i, 0]
    lat = df_final_test_for_map.iloc[i, 3]
    long = df_final_test_for_map.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([df_final_test_for_map['LATITUDE'].iloc[i], df_final_test_for_map['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b85ac16ccab2402281b503a1cd2d0db7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b85ac16ccab2402281b503a1cd2d0db7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b85ac16ccab2402281b503a1cd2d0db7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b85ac16ccab2402281b503a1cd2d0db7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# Accuracy
let_evaluate = neural_model.evaluate(X_test_scaled, y_test)
print('최종 손실률 : %f, 최종 accuracy : %f' % (let_evaluate[0], let_evaluate[1]))
# Out:
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1811 - sparse_categorical_accuracy: 0.9078
# 최종 손실률 : 0.181119, 최종 accuracy : 0.907801

# %%
# 예측하기
prediction = neural_model.predict(X_test_scaled) # test data의 예측치
prediction # 예측값이 어레이로 출력됨 따라서 argmax로 최대값 인덱스(위치) 출력
# Out:
# 5/5 [==============================] - 1s 5ms/step
# array([[9.96970534e-01, 1.31787452e-12, 3.02929175e-03, 1.01463321e-07],
#        [2.26903299e-04, 6.13027252e-04, 3.65504235e-01, 6.33655727e-01],
#        [9.82730925e-01, 1.12217852e-12, 1.72687694e-02, 2.36640105e-07],
#        [9.97404993e-01, 6.21037230e-15, 2.59495759e-03, 7.25615235e-10],
#        [2.32234690e-02, 4.86328815e-07, 9.72794712e-01, 3.98128852e-03],
#        [2.00423338e-21, 9.99528885e-01, 8.29336391e-11, 4.71173058e-04],
#        [8.85311475e-18, 9.96720970e-01, 5.06750109e-09, 3.27903777e-03],
#        [2.07321229e-03, 1.78000596e-06, 9.92597103e-01, 5.32791903e-03],
#        [4.41793789e-11, 2.00097524e-02, 1.39564171e-03, 9.78594482e-01],
#        [9.69979167e-01, 6.42796538e-10, 3.00165229e-02, 4.30131968e-06],
#        [8.67725849e-01, 5.36392708e-10, 1.32238656e-01, 3.55040320e-05],
#        [1.71618844e-08, 4.77537997e-02, 1.40590162e-03, 9.50840294e-01],
#        [1.13219594e-17, 9.97123420e-01, 5.26813748e-09, 2.87659420e-03],
#        [9.98910069e-01, 2.32920640e-16, 1.08996104e-03, 1.40015291e-10],
#        [1.26175575e-22, 9.99727428e-01, 1.22442933e-11, 2.72603880e-04],
#        [6.82112694e-01, 7.89021459e-10, 3.17862034e-01, 2.52639111e-05],
#        [9.97248590e-02, 1.23681367e-08, 8.99735272e-01, 5.39783970e-04],
#        [6.15153377e-18, 9.58631456e-01, 1.42974370e-08, 4.13685702e-02],
#        [1.84096338e-16, 9.64592218e-01, 5.81086930e-08, 3.54076996e-02],
#        [6.20992796e-05, 2.91401346e-04, 4.83109534e-01, 5.16537011e-01],
#        [8.57121722e-06, 9.48893372e-03, 2.07508937e-01, 7.82993555e-01],
#        [1.45379097e-12, 4.33044344e-01, 1.05281661e-05, 5.66945195e-01],
#        [7.28617122e-09, 6.27828240e-02, 2.58512306e-03, 9.34632063e-01],
#        [2.11246879e-06, 1.17559102e-03, 1.23873085e-01, 8.74949217e-01],
#        [9.88329411e-01, 8.46716967e-12, 1.16700362e-02, 6.20508217e-07],
#        [7.22414851e-02, 9.27001963e-07, 9.17367637e-01, 1.03899585e-02],
#        [7.56594527e-05, 2.69429875e-03, 2.39395484e-01, 7.57834494e-01],
#        [8.96097779e-01, 4.07357303e-09, 1.03857674e-01, 4.45192782e-05],
#        [2.11994135e-04, 9.31449249e-05, 7.53680050e-01, 2.46014819e-01],
#        [2.06023357e-22, 9.99888182e-01, 1.64166857e-11, 1.11782836e-04],
#        [4.35666919e-01, 3.46429818e-09, 5.64273059e-01, 6.00587591e-05]],
#       dtype=float32)

# %%
# 매우부적합 : 0
# 부적합 : 2
# 적합 : 3
# 매우적합 : 1

## 1. test data 실제 분류값과 ANN으로 예측된 값 데이터프레임 생성
df_tmp1 = pd.DataFrame({
    'Actual_Location_Score' :y_test,
    'Predicted_value_by_ANN' : np.argmax(prediction, axis = 1)
})

df_tmp2 = df[['GAS_STATION', 'DISTRICT','DONG', 'SCORE_CAT']]

df_final = pd.merge(df_tmp2, df_tmp1, left_index=True,right_index=True,how='inner'   )# 141개 =  test length랑 일치




### 2. 최종 입지 별로 공통된 구(지역)이 나올 수 있으니, 점수 확인해주고자 SCORE 행 추가
df_final = pd.merge(df_final, dfdf['SCORE'], left_index=True,right_index=True,how='left')


# 3.  클러스터링 결과와 연계해서, MFC가 필요한 1순위 지역 내 ANN으로 예측한 가장 적합한 주유소 추출
filterling = (
    (df_final['DISTRICT'].isin(['동대문구', '양천구', '동작구', '송파구', '구로구', '서대문구', '영등포구']))&
    (df_final['Actual_Location_Score'] == 1)&
    (df_final['Predicted_value_by_ANN'] == 1)
)

clustering_linkage_ANN = df_final.loc[filterling]
clustering_linkage_ANN

'''   
그런데 같은 구, 동에 여러 개 주유소가 선정됨
따라서 하나의 구에 하나만 설치한다고 가정하고
SCORE가 가장 높은 주유소에 MFC 입지 선정할 것임
'''
# Out:
# '   \n그런데 같은 구, 동에 여러 개 주유소가 선정됨\n따라서 하나의 구에 하나만 설치한다고 가정하고\nSCORE가 가장 높은 주유소에 MFC 입지 선정할 것임\n'

# %%
clustering_linkage_ANN
# Out:
#            GAS_STATION DISTRICT   DONG SCORE_CAT  Actual_Location_Score  \
# 49     삼미상사㈜ 장안킹셀프주유소      동대문구    장안동      매우적합                      1
# 52              삼영주유소      동대문구    장안동      매우적합                      1
# 55              배봉로주유소     동대문구    전농동      매우적합                      1
# 60         대성산업㈜청량리주유소     동대문구   청량리동      매우적합                      1
# 147       에이치지 가로공원주유소      양천구    신월동      매우적합                      1
# 149       동일석유㈜ 개나리주유소      양천구    신월동      매우적합                      1
# 165             양천구주유소      양천구     목동      매우적합                      1
# 235        SK에너지㈜양평주유소     영등포구  양평동3가      매우적합                      1
# 236       SK에너지㈜ 기린주유소     영등포구  양평동4가      매우적합                      1
# 243           ㈜정수에너지개발     영등포구    신길동      매우적합                      1
# 247            ㈜엠에스주유소     영등포구    대림동      매우적합                      1
# 249           (주)대청에너지     영등포구    대림동      매우적합                      1
# 251  현대오일뱅크㈜직영신대방셀프주유소      동작구   신대방동      매우적합                      1
#
#      Predicted_value_by_ANN     SCORE
# 49                        1  0.119815
# 52                        1  0.108965
# 55                        1  0.084279
# 60                        1  0.091912
# 147                       1  0.113783
# 149                       1  0.143189
# 165                       1  0.118080
# 235                       1  0.160287
# 236                       1  0.145911
# 243                       1  0.106042
# 247                       1  0.088108
# 249                       1  0.115939
# 251                       1  0.146005

# %%
# 용이가 한 코드로 지도시각화
import folium as g

df_final_all_selection_for_map = pd.merge(df, clustering_linkage_ANN)

seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df_final_all_selection_for_map)):
    name = df_final_all_selection_for_map.iloc[i, 0]
    lat = df_final_all_selection_for_map.iloc[i, 3]
    long = df_final_all_selection_for_map.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([df_final_all_selection_for_map['LATITUDE'].iloc[i], df_final_all_selection_for_map['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_73afc159eadc4394bbc45ac54374fbab%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_73afc159eadc4394bbc45ac54374fbab%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_73afc159eadc4394bbc45ac54374fbab%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_73afc159eadc4394bbc45ac54374fbab%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# 구 별로 SCORE가 가장 높은 주유소 선정
df_tmp2 = clustering_linkage_ANN.groupby('DISTRICT')['SCORE'].max().reset_index()
# groupby로 기존 데이터 추출하려니 구별로 최대값은 추출되나 해당된는 주유소 이름이 매칭이 안됨, 귀찮아서 구별로 max 점수는 하나씩 밖에 없으니 합침
df_final_selection = pd.merge(left =df_tmp2, right=clustering_linkage_ANN,how='left', left_on=['DISTRICT','SCORE'], 
                  right_on=['DISTRICT','SCORE'])
df_final_selection


''' 
결론 : 클러스터링 결과와 연계해서 보니, 최종 MFC 설치 지역은 동대문구, 동작구, 양천구, 영등포구 이고,
        최종 MFC 입지선정은 다음과 같은 4개 주유소가 선정됨
'''
# Out:
# ' \n결론 : 클러스터링 결과와 연계해서 보니, 최종 MFC 설치 지역은 동대문구, 동작구, 양천구, 영등포구 이고,\n        최종 MFC 입지선정은 다음과 같은 4개 주유소가 선정됨\n'

# %%
# 용이가 한 코드로 지도시각화
import folium as g

df_final_selection_for_map = pd.merge(df, df_final_selection)

seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df_final_selection_for_map)):
    name = df_final_selection_for_map.iloc[i, 0]
    lat = df_final_selection_for_map.iloc[i, 3]
    long = df_final_selection_for_map.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([df_final_selection_for_map['LATITUDE'].iloc[i], df_final_selection_for_map['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3090183af40b48beaad848877403bf68%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3090183af40b48beaad848877403bf68%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3090183af40b48beaad848877403bf68%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3090183af40b48beaad848877403bf68%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#!pip3 install plotnine

# %%
import plotnine
from plotnine import *

# %%
df_accuracy = pd.DataFrame({
    'Algorithm' : ['Logistic_Reg',  'Knn', 'Decision Tree', 'Random_forest','Gradient_boosting_classifi', 'ANN'],
    'Score': [round(accuracy_score_lr[1],4),round(accuracy_score_knn[1],4),  round(accuracy_score_clf[1], 4), 
              round(accuracy_score_forest[1], 4),
             round(accuracy_score_gb[1], 4), 
              round(let_evaluate[1], 3)]})
df_accuracy
# Out:
#                     Algorithm   Score
# 0                Logistic_Reg  0.6667
# 1                         Knn  0.6667
# 2               Decision Tree  0.7518
# 3               Random_forest  0.7589
# 4  Gradient_boosting_classifi  0.7660
# 5                         ANN  0.9080

# %%
p = ggplot(df_accuracy, aes(x = 'Algorithm',
                            y = 'Score',
                            fill = 'Algorithm',)) + geom_col(alpha = 0.7)
p + coord_flip() + geom_text(aes(label = 'Score')) + ggtitle('Comparison of accuracy by algorithm')
# Out:
# <ggplot: (82425928951)>

# %% [markdown]
# ## Appendix

# %%
import folium as g

# %%
# 서울 시 내 MFC 장소로 적합한 주유소 위치후보.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df[df['SCORE_CAT'] == '적합'])):
    marker = g.Marker([df[df['SCORE_CAT'] == '적합']['LATITUDE'].iloc[i], df[df['SCORE_CAT'] == '적합']['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'))
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d434c1a40db24d679e455c6cf9857fe9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d434c1a40db24d679e455c6cf9857fe9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d434c1a40db24d679e455c6cf9857fe9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d434c1a40db24d679e455c6cf9857fe9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# groupby 집계함수로 구별로 max값 추출한 뒤 클러스터링 결과와 결합하여 구당 하나의 최적 위치 설정.
optdf = df.groupby('DISTRICT').max().loc[['동대문구', '양천구', '동작구', '송파구', '구로구', '서대문구', '영등포구']].reset_index()
optdf
# Out:
#   DISTRICT           GAS_STATION    DONG   LATITUDE   LONGITUDE    AREA  \
# 0     동대문구   현대오일뱅크㈜ 직영 스피드 주유소      휘경동  37.603648  127.069418  2080.0
# 1      양천구            형산석유㈜ 원주유소     신정동  37.546767  126.882153  2056.0
# 2      동작구        현대오일뱅크㈜흑석셀프주유소     흑석동  37.513554  126.981970  1676.0
# 3      송파구                훼미리주유소     풍납동  37.527012  127.147838  2586.0
# 4      구로구     현대오일뱅크㈜직영 신오류주유소       항동  37.507698  126.899784  1971.0
# 5     서대문구    현대오일뱅크(주) 직영 연세주유소     홍제동  37.595442  126.950102  1260.0
# 6     영등포구  현대오일뱅크㈜직영 영등포현대셀프주유소  영등포동7가  37.538442  126.927479  3321.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8772000.0     3.507059    22.430746     16.001545     635   12307
# 1  12630000.0    22.271100     5.519070     20.531385     539   12174
# 2  18440000.0    18.113277    12.875900     12.052601     952   11637
# 3  19500000.0    12.966467    27.233535     10.609878     647   15815
# 4  11520000.0    24.241182     6.155432     19.234698    1583   10820
# 5  12900000.0    13.745000    13.589265     16.916960     416    9806
# 6  26900000.0    18.157095     7.964661     15.493111    1383   12158
#
#    POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 0    43733      10     21      14      매우적합
# 1    51685       5     49       7      매우적합
# 2    46479      10      7       5      매우적합
# 3    42885       3     13      10      매우적합
# 4    42423       5      9       7      매우적합
# 5    34119      12      8      10      매우적합
# 6    39557      11     15      17      매우적합

# %%
# 서울 시 내 입지순위 1위 지역 MFC 장소로 적합한 주유소 위치. 지도 시각화, 기호 누르면 해당 주유소의 이름과 위경도 추출해줌.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(optdf)):
    name = optdf.iloc[i, 1]
    lat = optdf.iloc[i, 3]
    long = optdf.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([optdf['LATITUDE'].iloc[i], optdf['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_237758a250a3467aa129358093d98fba%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_237758a250a3467aa129358093d98fba%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_237758a250a3467aa129358093d98fba%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_237758a250a3467aa129358093d98fba%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#!pip install --pre pycaret

# %%
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 from pycaret.classification import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
s = setup(df.iloc[:,[5,6,7,8,9,12,13,14,15,16]], target = 'SCORE_CAT')

# %%
top5_models = compare_models(fold = 5, round = 3, sort = 'AUC', n_select = 5)

# %%
top5_models

# %%
model_qda = create_model('qda', fold = 5)
model_lda = create_model('lda', fold = 5)
model_lightgbm = create_model('lightgbm', fold = 5)
model_gbc = create_model('gbc', fold = 5)
model_xgboost = create_model('xgboost', fold = 5)

# %%
total_models = []
total_models.append([model_qda, model_lda, model_lightgbm, model_gbc, model_xgboost])

# %%
total_models

# %%
model_qda = tune_model(model_qda, fold=5, optimize = 'AUC', choose_better = True)
model_lda = tune_model(model_lda, fold=5, optimize = 'AUC', choose_better = True)
model_lightgbm = tune_model(model_lightgbm, fold=5, optimize = 'AUC', choose_better = True)
model_gbc = tune_model(model_gbc, fold=5, optimize = 'AUC', choose_better = True)
model_xgboost = tune_model(model_xgboost, fold=5, optimize = 'AUC', choose_better = True)

# %%
tuned_models = [model_qda, model_lda, model_lightgbm, model_gbc, model_xgboost]

# %%
tuned_models

# %%
total_models

# %%
plot_model(model_xgboost, plot='auc')

# %%
plot_model(model_xgboost, plot='feature')
